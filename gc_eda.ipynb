# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv('train.csv')

# %%
train.describe()
# Out:
#                   id         target            A_1            A_2  \
# count  400665.000000  400665.000000  296778.000000  299259.000000
# mean   399800.032122       0.005104       0.667761       1.012916
# std    231121.964781       0.071260       0.277211       0.422273
# min         1.000000       0.000000       0.000000       0.000000
# 25%    199609.000000       0.000000       0.415975       0.645902
# 50%    399899.000000       0.000000       0.640886       1.021599
# 75%    600178.000000       0.000000       0.878877       1.399283
# max    799999.000000       1.000000       1.421853       2.205987
#
#                  B_1           B_2            B_3            B_4  \
# count  143221.000000  80125.000000  400665.000000  400665.000000
# mean        0.224665     73.428006       1.301113       2.583867
# std         0.429837     43.326116       0.815894       1.325857
# min         0.000000      0.000000       0.000000      -1.000000
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400665 entries, 0 to 400664
# Data columns (total 36 columns):
# id        400665 non-null int64
# target    400665 non-null int64
# A_1       296778 non-null float64
# A_2       299259 non-null float64
# B_1       143221 non-null float64
# B_2       80125 non-null float64
# B_3       400665 non-null float64
# B_4       400665 non-null int64
# B_5       32040 non-null object
# B_6       23789 non-null object
# B_7       85958 non-null float64
# B_8       400665 non-null float64
# B_9       400665 non-null int64
# B_10      313160 non-null float64
# B_11      400665 non-null int64
# B_12      400665 non-null int64
# B_13      400665 non-null int64
# B_14      291518 non-null object
# B_15      382705 non-null object
# C_1       398892 non-null float64
# C_2       398892 non-null float64
# C_3       398893 non-null float64
# C_4       398892 non-null float64
# C_5       398892 non-null float64
# C_6       398892 non-null float64
# ...

# %%
train.head(15)
# Out:
#     id  target       A_1       A_2  B_1    B_2       B_3  B_4  B_5  B_6  \
# 0    1       0  0.415975  0.645902  NaN    NaN  0.000000    1  NaN  NaN
# 1    3       0  0.176933  0.273043  NaN    NaN  0.832555    4  NaN  NaN
# 2    5       0  0.415975  0.645902  0.0    NaN  0.832555    1  NaN  NaN
# 3    8       0  0.228507  0.494354  0.0    NaN  0.832555    1  NaN  NaN
# 4   10       0  0.969242  1.586129  0.0  100.0  1.962179    4  NaN  NaN
# 5   11       0  0.435877  0.713346  0.0    NaN  0.000000    1  NaN  NaN
# 6   16       0  0.176933  0.273043  NaN    NaN  1.048147    4  NaN  NaN
# 7   17       0       NaN       NaN  NaN    NaN  0.832555    2  NaN  NaN
# 8   19       0  0.435877  0.713346  0.0    NaN  0.000000    1  NaN  NaN
# 9   22       0  0.176933  0.273043  NaN    NaN  1.700109    2  NaN  NaN
# 10  23       0  0.415975  0.645902  NaN    NaN  0.000000    2  NaN  NaN
# 11  24       0       NaN       NaN  NaN    NaN  0.000000    3  NaN  NaN
# ...

# %%
train.tail(15)
# Out:
#             id  target       A_1       A_2  B_1    B_2       B_3  B_4  B_5  \
# 400650  799973       0       NaN       NaN  NaN  100.0  1.844234    2  NaN
# 400651  799974       0  0.759513  1.177655  NaN    NaN  1.268636    1  NaN
# 400652  799976       0       NaN       NaN  0.0    NaN  2.541942    5  NaN
# 400653  799979       0  1.129836  1.661094  NaN    NaN  0.832555    1  NaN
# 400654  799980       0  0.176933  0.273043  0.0    NaN  0.000000    3  NaN
# 400655  799985       0  0.603706  0.848901  NaN    NaN  0.000000    2  NaN
# 400656  799988       0  0.243136  0.447136  NaN    NaN  0.000000    4  NaN
# 400657  799990       0  1.011836  1.477658  0.0  100.0  2.459621    3  NaN
# 400658  799992       0       NaN       NaN  NaN    NaN  1.758136   -1  NaN
# 400659  799993       0       NaN       NaN  NaN    NaN  2.074624    3  NaN
# 400660  799994       0  0.176933  0.273043  0.0    NaN  0.000000    4  NaN
# ...

# %%
train.A_1.count()
# Out:
# 296778

# %%
train.A_2.count()
# Out:
# 299259

# %%
# a_2 has fewer missing values

examine_a = train[['id','target','A_1','A_2']]

# %%
examine_a.head()
# Out:
#    id  target       A_1       A_2
# 0   1       0  0.415975  0.645902
# 1   3       0  0.176933  0.273043
# 2   5       0  0.415975  0.645902
# 3   8       0  0.228507  0.494354
# 4  10       0  0.969242  1.586129

# %%
ax = plt.scatter('A_1','A_2', data=examine_a)
plt.show()

# %%
ax = sns.relplot('A_1','A_2', hue='target', data=examine_a)
plt.show()

# looks like there are no failures where there are values for both A cols

# %%
examine_a.loc[examine_a['A_1'].isnull()]
# Out:
#             id  target  A_1  A_2
# 7           17       0  NaN  NaN
# 11          24       0  NaN  NaN
# 12          26       0  NaN  NaN
# 22          39       0  NaN  NaN
# 28          47       0  NaN  NaN
# 29          49       0  NaN  NaN
# 32          52       0  NaN  NaN
# 33          54       0  NaN  NaN
# 46          79       0  NaN  NaN
# 57          98       0  NaN  NaN
# 61         103       0  NaN  NaN
# 62         105       0  NaN  NaN
# 63         107       0  NaN  NaN
# 67         114       0  NaN  NaN
# 68         116       0  NaN  NaN
# 69         119       0  NaN  NaN
# 74         128       0  NaN  NaN
# 77         132       0  NaN  NaN
# 78         133       0  NaN  NaN
# 82         140       0  NaN  NaN
# 84         143       0  NaN  NaN
# 85         146       0  NaN  NaN
# 86         149       0  NaN  NaN
# 87         150       0  NaN  NaN
# 89         153       0  NaN  NaN
# 92         157       0  NaN  NaN
# 94         159       0  NaN  NaN
# ...

# %%
examine_a.loc[examine_a['target'] == 1]
# Out:
#             id  target       A_1       A_2
# 438        826       1  0.384503  0.873202
# 500        930       1  0.603706  0.848901
# 503        933       1       NaN  1.198930
# 518        963       1  0.415975  0.645902
# 813       1580       1       NaN       NaN
# 1116      2173       1  0.342765  0.733435
# 1468      2881       1       NaN       NaN
# 1612      3163       1  1.033846  1.539238
# 1777      3501       1  0.649197  1.197015
# 1849      3649       1  1.254614  1.858668
# 2548      5003       1  0.669905  0.455207
# 2781      5463       1  0.626417  0.816552
# 2878      5660       1  0.858780  1.399283
# 3216      6357       1  0.782107  0.809428
# 3408      6717       1  0.435877  0.713346
# 3531      6966       1  0.766701  0.981211
# 3534      6970       1  0.639009  1.194455
# 3978      7862       1  0.899797  1.028730
# 4317      8541       1  1.051644  1.594596
# 4442      8792       1  1.011836  1.477658
# 4461      8828       1  0.861673  1.428634
# ...

# %%
# want to bin also

fig, axs = plt.subplots(1,2)

axs[0].hist(examine_a['A_1'].dropna(), bins=10)
axs[1].hist(examine_a['A_2'].dropna(), bins=10)

plt.show()
